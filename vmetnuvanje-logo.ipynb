# %%
from PIL import Image
img = Image.open('logo.png')
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=468x647 at 0x1A474AB5280>

# %%
from IPython.display import Audio, Image, YouTubeVideo
